# %%
# import cv2
# vidcap = cv2.VideoCapture('C:/Users/faraz/OneDrive - Ultranav/DTU/Semester 3/Deep Learning  - 02456/CPH bike data/FILE0006.mp4')
# def getFrame(sec):
#     vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
#     hasFrames,image = vidcap.read()
#     if hasFrames:
#         cv2.imwrite("image"+str(count)+".jpg", image)     # save frame as JPG file
#     return hasFrames
# sec = 0
# frameRate = 0.5 #//it will capture image in each 0.5 second
# count=1
# success = getFrame(sec)
# while success:
#     count = count + 1
#     sec = sec + frameRate
#     sec = round(sec, 2)
#     success = getFrame(sec)

# %%
import os
import cv2
pathOut = r"C:/Users/faraz/OneDrive - Ultranav/DTU/Semester 3/Deep Learning  - 02456/Out/"
count = 0
counter = 0.5
listing = os.listdir(r'C:/Users/faraz/OneDrive - Ultranav/DTU/Semester 3/Deep Learning  - 02456/CPH bike data/')
for vid in listing:
    vid = r"C:/Users/faraz/OneDrive - Ultranav/DTU/Semester 3/Deep Learning  - 02456/CPH bike data/"+vid
    cap = cv2.VideoCapture(vid)
    count = 0
    counter += 0.5
    success = True
    while success:
        success,image = cap.read()
        print('read a new frame:',success)
        if count%1 == 0 :
             cv2.imwrite(pathOut + 'frame%d.jpg'%count,image)
        count+=1
# Out:
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# read a new frame: True
# ...
